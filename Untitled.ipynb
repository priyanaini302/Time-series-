# %%
from nsepy import get_history as gh
import datetime as dt

# %%
start=dt.datetime(2021,7,1)
end=dt.datetime(2022,7,28)
skt_data=gh(symbol='TATACOFFEE',start=start ,end=end)
# Out:
# Exception in thread Thread-59 (get_history):
# Traceback (most recent call last):
#   File "E:\software installtalation paths\anaconda\envs\time\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "E:\software installtalation paths\anaconda\envs\time\Lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\software installtalation paths\anaconda\envs\time\Lib\site-packages\nsepy\history.py", line 138, in get_history
# Exception in thread Thread-57 (get_history):
# Traceback (most recent call last):
#   File "E:\software installtalation paths\anaconda\envs\time\Lib\threading.py", line 1045, in _bootstrap_inner
#     return get_history_quanta(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\software installtalation paths\anaconda\envs\time\Lib\site-packages\nsepy\history.py", line 143, in get_history_quanta
# ...
